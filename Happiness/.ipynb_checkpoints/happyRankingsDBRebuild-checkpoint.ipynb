# %% [markdown]
# # World Happiness Rankings Database Rebuild

# %%
# Pandas and Matplotlib
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# Python SQL toolkit and Object Relational Mapper
from sqlalchemy import create_engine, func, distinct
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# SQLite 
import sqlite3
from sqlite3 import Error

# General tools
import os
import csv
import itertools
import glob

# %%
# Brute force csv read -- just in case
rankings2015 = pd.read_csv(r'c:/Users/Rudy/Desktop/DataViz/happiness-project/Happiness/data/dataRebuild/2015.csv')
rankings2016 = pd.read_csv(r'c:/Users/Rudy/Desktop/DataViz/happiness-project/Happiness/data/dataRebuild/2016.csv')
rankings2017 = pd.read_csv(r'c:/Users/Rudy/Desktop/DataViz/happiness-project/Happiness/data/dataRebuild/2017.csv')
rankings2018 = pd.read_csv(r'c:/Users/Rudy/Desktop/DataViz/happiness-project/Happiness/data/dataRebuild/2018.csv')
rankings2019 = pd.read_csv(r'c:/Users/Rudy/Desktop/DataViz/happiness-project/Happiness/data/dataRebuild/2019.csv')

# %%
# New dataset path
path = r'c:/Users/Rudy/Desktop/DataViz/happiness-project/Happiness/data/dataRebuild'

# %%
# Function to assign csv files to a single array
def getCSVFiles():
    # Calls ALL csv files from the data path
    csvFiles = glob.glob(os.path.join(path, '*.csv'))

    # Empty array to assign the csv files
    dataframes = []

    # Assigns dataframes to empty array
    for csv in csvFiles:
        df = pd.read_csv(csv)
        dataframes.append(df)
    
    print(dataframes)

# %%
# Function to create csv names
def createCSVNames():
    # Empty array to hold the new file names
    csvNames = []
    
    # Years of Rankings data
    years = ['2015', '2016', '2017', '2018', '2019']
    
    # Loop through desired years to create new names for each csv data file
    for year in years:
        csvName = 'rankings' + year
        csvNames.append(csvName)
        
    print(csvNames)

# %%
# Verify function and array created within function
createCSVNames()
print('New data names:', csvNames)
# Out:
# ['rankings2015', 'rankings2016', 'rankings2017', 'rankings2018', 'rankings2019']
# New data names: ['rankings2015', 'rankings2016', 'rankings2017', 'rankings2018', 'rankings2019']

# %%
# Function to assign new csv names to each dataframe
def assignDataframes():
    # Empty array to hold newly labeled dataframes
    rankingsDF = []
    
    # Loops through dataframes and assigns the new csv names
    for df in dataframes:
        for csv in csvNames:
            csv = df
            df_new.append(csv)
    
    print(rankingsDF)

# %%
# Verify calling of labeled index to output desired dataframe
rankings2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...
