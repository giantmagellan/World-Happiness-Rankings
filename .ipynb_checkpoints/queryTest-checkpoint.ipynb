# %% [markdown]
# ### Edits tables for data to be used in flask app

# %%
# Dependencies
# ------------
# Imports method used for connecting to DBs
from sqlalchemy import create_engine

# Methods needed to abstrct classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allows for the creation of column types
from sqlalchemy import Column, Integer, String, Float

# %%
# Sets an object to utilize the default declarative base in SQLAlchemy
Base = declarative_base()

# %%
# Creating a list of class names to assign to each table
rank_classes = ["Rankings2015", "Rankings2016", "Rankings2017", "Rankings2018", "Rankings2019"]

rank_classDict = {}
for name in names:
    rank_classDict[name] =

# %%
# Class to serve as anchor point for the table
class Rankings2015(Base):
    __tablename__ = 'rankings2015'
    overall_rank = Column(Integer, primary_key=True)
    country = Column(String)
    score = Column(Float)
    gdp_per_capita = Column(Float)
    social_support = Column(Float)
    healthy_life_expectancy = Column(Float)
    freedom_to_choose = Column(Float)
    generosity = Column(Float)
    perception_of_corruption = Column(Float)
    latitude = Column(Float)
    longitude = Column(Float)

# %%
# Class to serve as anchor point for the table
class Rankings2016(Base):
    __tablename__ = 'rankings2016'
    overall_rank = Column(Integer, primary_key=True)
    country = Column(String)
    score = Column(Float)
    gdp_per_capita = Column(Float)
    social_support = Column(Float)
    healthy_life_expectancy = Column(Float)
    freedom_to_choose = Column(Float)
    generosity = Column(Float)
    perception_of_corruption = Column(Float)
    latitude = Column(Float)
    longitude = Column(Float)

# %%
# Class to serve as anchor point for the table
class Rankings2017(Base):
    __tablename__ = 'rankings2017'
    overall_rank = Column(Integer, primary_key=True)
    country = Column(String)
    score = Column(Float)
    gdp_per_capita = Column(Float)
    social_support = Column(Float)
    healthy_life_expectancy = Column(Float)
    freedom_to_choose = Column(Float)
    generosity = Column(Float)
    perception_of_corruption = Column(Float)
    latitude = Column(Float)
    longitude = Column(Float)

# %%
# Class to serve as anchor point for the table
class Rankings2018(Base):
    __tablename__ = 'rankings2018'
    overall_rank = Column(Integer, primary_key=True)
    country = Column(String)
    score = Column(Float)
    gdp_per_capita = Column(Float)
    social_support = Column(Float)
    healthy_life_expectancy = Column(Float)
    freedom_to_choose = Column(Float)
    generosity = Column(Float)
    perception_of_corruption = Column(Float)
    latitude = Column(Float)
    longitude = Column(Float)

# %%
# Class to serve as anchor point for the table
class Rankings2019(Base):
    __tablename__ = 'rankings2019'
    overall_rank = Column(Integer, primary_key=True)
    country = Column(String)
    score = Column(Float)
    gdp_per_capita = Column(Float)
    social_support = Column(Float)
    healthy_life_expectancy = Column(Float)
    freedom_to_choose = Column(Float)
    generosity = Column(Float)
    perception_of_corruption = Column(Float)
    latitude = Column(Float)
    longitude = Column(Float)

# %%
# Create Database Connection
engine = create_engine('sqlite:///../happiness-project/yearlyRankingsDB.sqlite')
Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Test query for flask app
results = session.query(Rankings.country, Rankings.score, Rankings.gdp_per_capita).all()
results
# Out:
# []

# %%
from sqlalchemy import inspect
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['Happy_Rankings', 'Rankings']

# %%
# Append data to list 
all_rankings = []
for country, score, gdp_per_capita in results:
    rankings_dict = {}
    rankings_dict['country'] = country
    rankings_dict['score'] = score
    rankings_dict['gdp_per_capita'] = gdp_per_capita
    all_rankings.append(rankings_dict)
all_rankings
# Out:
# [{'country': 'Finland', 'score': 7.769, 'gdp_per_capita': 1.34},
#  {'country': 'Denmark', 'score': 7.6, 'gdp_per_capita': 1.383},
#  {'country': 'Norway',
#   'score': 7.553999999999999,
#   'gdp_per_capita': 1.4880000000000002},
#  {'country': 'Iceland', 'score': 7.494, 'gdp_per_capita': 1.38},
#  {'country': 'Netherlands',
#   'score': 7.4879999999999995,
#   'gdp_per_capita': 1.396},
#  {'country': 'Switzerland', 'score': 7.48, 'gdp_per_capita': 1.452},
#  {'country': 'Sweden', 'score': 7.343, 'gdp_per_capita': 1.3869999999999998},
#  {'country': 'New Zealand',
#   'score': 7.307,
#   'gdp_per_capita': 1.3030000000000002},
#  {'country': 'Canada', 'score': 7.278, 'gdp_per_capita': 1.365},
#  {'country': 'Austria', 'score': 7.246, 'gdp_per_capita': 1.376},
#  {'country': 'Australia',
#   'score': 7.228,
#   'gdp_per_capita': 1.3719999999999999},
#  {'country': 'Costa Rica',
#   'score': 7.167000000000001,
#   'gdp_per_capita': 1.034},
#  {'country': 'Israel', 'score': 7.138999999999999, 'gdp_per_capita': 1.276},
#  {'country': 'Luxembourg', 'score': 7.09, 'gdp_per_capita': 1.609},
#  {'country': 'United Kingdom',
#   'score': 7.053999999999999,
#   'gdp_per_capita': 1.3330000000000002},
#  {'country': 'Ireland', 'score': 7.021, 'gdp_per_capita': 1.499},
#  {'country': 'Germany', 'score': 6.985, 'gdp_per_capita': 1.3730000000000002},
#  {'country': 'Belgium',
#   'score': 6.922999999999999,
#   'gdp_per_capita': 1.3559999999999999},
#  {'country': 'United States', 'score': 6.892, 'gdp_per_capita': 1.433},
#  {'country': 'Czech Republic',
#   'score': 6.852,
#   'gdp_per_capita': 1.2690000000000001},
#  {'country': 'United Arab Emirates',
#   'score': 6.825,
#   'gdp_per_capita': 1.5030000000000001},
#  {'country': 'Malta', 'score': 6.726, 'gdp_per_capita': 1.3},
#  {'country': 'Mexico', 'score': 6.595, 'gdp_per_capita': 1.07},
#  {'country': 'France', 'score': 6.5920000000000005, 'gdp_per_capita': 1.324},
#  {'country': 'Taiwan', 'score': 6.446000000000001, 'gdp_per_capita': 1.368},
#  {'country': 'Chile', 'score': 6.444, 'gdp_per_capita': 1.159},
#  {'country': 'Guatemala', 'score': 6.436, 'gdp_per_capita': 0.8},
#  {'country': 'Saudi Arabia', 'score': 6.375, 'gdp_per_capita': 1.403},
#  {'country': 'Qatar', 'score': 6.374, 'gdp_per_capita': 1.6840000000000002},
#  {'country': 'Spain', 'score': 6.354, 'gdp_per_capita': 1.286},
#  {'country': 'Panama', 'score': 6.321000000000001, 'gdp_per_capita': 1.149},
#  {'country': 'Brazil', 'score': 6.3, 'gdp_per_capita': 1.004},
#  {'country': 'Uruguay', 'score': 6.292999999999999, 'gdp_per_capita': 1.124},
#  {'country': 'Singapore',
#   'score': 6.2620000000000005,
#   'gdp_per_capita': 1.5719999999999998},
#  {'country': 'El Salvador',
#   'score': 6.252999999999999,
#   'gdp_per_capita': 0.794},
#  {'country': 'Italy', 'score': 6.223, 'gdp_per_capita': 1.294},
#  {'country': 'Bahrain', 'score': 6.199, 'gdp_per_capita': 1.3619999999999999},
#  {'country': 'Slovakia', 'score': 6.1979999999999995, 'gdp_per_capita': 1.246},
#  {'country': 'Trinidad & Tobago',
#   'score': 6.192,
#   'gdp_per_capita': 1.2309999999999999},
#  {'country': 'Poland', 'score': 6.182, 'gdp_per_capita': 1.206},
#  {'country': 'Uzbekistan',
#   'score': 6.1739999999999995,
#   'gdp_per_capita': 0.745},
#  {'country': 'Lithuania', 'score': 6.149, 'gdp_per_capita': 1.238},
#  {'country': 'Colombia', 'score': 6.125, 'gdp_per_capita': 0.985},
#  {'country': 'Slovenia', 'score': 6.117999999999999, 'gdp_per_capita': 1.258},
#  {'country': 'Nicaragua',
#   'score': 6.105,
#   'gdp_per_capita': 0.6940000000000001},
#  {'country': 'Kosovo', 'score': 6.1, 'gdp_per_capita': 0.882},
#  {'country': 'Argentina', 'score': 6.086, 'gdp_per_capita': 1.092},
#  {'country': 'Romania', 'score': 6.07, 'gdp_per_capita': 1.162},
#  {'country': 'Cyprus', 'score': 6.046, 'gdp_per_capita': 1.263},
#  {'country': 'Ecuador', 'score': 6.028, 'gdp_per_capita': 0.912},
#  {'country': 'Kuwait', 'score': 6.021, 'gdp_per_capita': 1.5},
#  {'country': 'Thailand', 'score': 6.007999999999999, 'gdp_per_capita': 1.05},
#  {'country': 'Latvia', 'score': 5.94, 'gdp_per_capita': 1.187},
#  {'country': 'South Korea', 'score': 5.895, 'gdp_per_capita': 1.301},
#  {'country': 'Estonia', 'score': 5.893, 'gdp_per_capita': 1.237},
#  {'country': 'Jamaica', 'score': 5.89, 'gdp_per_capita': 0.831},
#  {'country': 'Mauritius', 'score': 5.888, 'gdp_per_capita': 1.12},
#  {'country': 'Japan', 'score': 5.886, 'gdp_per_capita': 1.327},
#  {'country': 'Honduras', 'score': 5.86, 'gdp_per_capita': 0.642},
#  {'country': 'Kazakhstan', 'score': 5.809, 'gdp_per_capita': 1.173},
#  {'country': 'Bolivia', 'score': 5.779, 'gdp_per_capita': 0.7759999999999999},
#  {'country': 'Hungary',
#   'score': 5.757999999999999,
#   'gdp_per_capita': 1.2009999999999998},
#  {'country': 'Paraguay', 'score': 5.742999999999999, 'gdp_per_capita': 0.855},
#  {'country': 'Northern Cyprus', 'score': 5.718, 'gdp_per_capita': 1.263},
#  {'country': 'Peru', 'score': 5.697, 'gdp_per_capita': 0.96},
#  {'country': 'Portugal', 'score': 5.693, 'gdp_per_capita': 1.2209999999999999},
#  {'country': 'Pakistan', 'score': 5.653, 'gdp_per_capita': 0.677},
#  {'country': 'Russia', 'score': 5.648, 'gdp_per_capita': 1.183},
#  {'country': 'Philippines', 'score': 5.631, 'gdp_per_capita': 0.807},
#  {'country': 'Serbia', 'score': 5.603, 'gdp_per_capita': 1.004},
#  {'country': 'Moldova', 'score': 5.529, 'gdp_per_capita': 0.685},
#  {'country': 'Libya', 'score': 5.525, 'gdp_per_capita': 1.044},
#  {'country': 'Montenegro', 'score': 5.523, 'gdp_per_capita': 1.051},
#  {'country': 'Tajikistan',
#   'score': 5.4670000000000005,
#   'gdp_per_capita': 0.493},
#  {'country': 'Croatia', 'score': 5.432, 'gdp_per_capita': 1.155},
#  {'country': 'Hong Kong', 'score': 5.43, 'gdp_per_capita': 1.4380000000000002},
#  {'country': 'Dominican Republic', 'score': 5.425, 'gdp_per_capita': 1.015},
#  {'country': 'Bosnia and Herzegovina',
#   'score': 5.386,
#   'gdp_per_capita': 0.945},
#  {'country': 'Turkey', 'score': 5.372999999999999, 'gdp_per_capita': 1.183},
#  {'country': 'Malaysia',
#   'score': 5.3389999999999995,
#   'gdp_per_capita': 1.2209999999999999},
#  {'country': 'Belarus', 'score': 5.3229999999999995, 'gdp_per_capita': 1.067},
#  {'country': 'Greece', 'score': 5.287000000000001, 'gdp_per_capita': 1.181},
#  {'country': 'Mongolia', 'score': 5.285, 'gdp_per_capita': 0.948},
#  {'country': 'North Macedonia', 'score': 5.274, 'gdp_per_capita': 0.983},
#  {'country': 'Nigeria', 'score': 5.265, 'gdp_per_capita': 0.696},
#  {'country': 'Kyrgyzstan', 'score': 5.261, 'gdp_per_capita': 0.551},
#  {'country': 'Turkmenistan',
#   'score': 5.247000000000001,
#   'gdp_per_capita': 1.052},
#  {'country': 'Algeria', 'score': 5.211, 'gdp_per_capita': 1.002},
#  {'country': 'Morocco',
#   'score': 5.207999999999999,
#   'gdp_per_capita': 0.8009999999999999},
#  {'country': 'Azerbaijan',
#   'score': 5.207999999999999,
#   'gdp_per_capita': 1.043},
#  {'country': 'Lebanon', 'score': 5.197, 'gdp_per_capita': 0.987},
#  {'country': 'Indonesia',
#   'score': 5.192,
#   'gdp_per_capita': 0.9309999999999999},
#  {'country': 'China', 'score': 5.191, 'gdp_per_capita': 1.0290000000000001},
#  {'country': 'Vietnam', 'score': 5.175, 'gdp_per_capita': 0.741},
#  {'country': 'Bhutan', 'score': 5.082, 'gdp_per_capita': 0.813},
#  {'country': 'Cameroon', 'score': 5.044, 'gdp_per_capita': 0.5489999999999999},
#  {'country': 'Bulgaria', 'score': 5.011, 'gdp_per_capita': 1.092},
#  {'country': 'Ghana', 'score': 4.996, 'gdp_per_capita': 0.611},
#  {'country': 'Ivory Coast', 'score': 4.944, 'gdp_per_capita': 0.569},
#  {'country': 'Nepal', 'score': 4.913, 'gdp_per_capita': 0.446},
#  {'country': 'Jordan',
#   'score': 4.906000000000001,
#   'gdp_per_capita': 0.8370000000000001},
#  {'country': 'Benin', 'score': 4.883, 'gdp_per_capita': 0.39299999999999996},
#  {'country': 'Congo (Brazzaville)',
#   'score': 4.812,
#   'gdp_per_capita': 0.6729999999999999},
#  {'country': 'Gabon', 'score': 4.7989999999999995, 'gdp_per_capita': 1.057},
#  {'country': 'Laos', 'score': 4.796, 'gdp_per_capita': 0.764},
#  {'country': 'South Africa',
#   'score': 4.7219999999999995,
#   'gdp_per_capita': 0.96},
#  {'country': 'Albania',
#   'score': 4.718999999999999,
#   'gdp_per_capita': 0.9470000000000001},
#  {'country': 'Venezuela', 'score': 4.707, 'gdp_per_capita': 0.96},
#  {'country': 'Cambodia', 'score': 4.7, 'gdp_per_capita': 0.574},
#  {'country': 'Palestinian Territories',
#   'score': 4.696000000000001,
#   'gdp_per_capita': 0.657},
#  {'country': 'Senegal', 'score': 4.681, 'gdp_per_capita': 0.45},
#  {'country': 'Somalia', 'score': 4.668, 'gdp_per_capita': 0.0},
#  {'country': 'Namibia', 'score': 4.638999999999999, 'gdp_per_capita': 0.879},
#  {'country': 'Niger', 'score': 4.628, 'gdp_per_capita': 0.138},
#  {'country': 'Burkina Faso', 'score': 4.587, 'gdp_per_capita': 0.331},
#  {'country': 'Armenia', 'score': 4.559, 'gdp_per_capita': 0.85},
#  {'country': 'Iran', 'score': 4.548, 'gdp_per_capita': 1.1},
#  {'country': 'Guinea', 'score': 4.534, 'gdp_per_capita': 0.38},
#  {'country': 'Georgia', 'score': 4.519, 'gdp_per_capita': 0.8859999999999999},
#  {'country': 'Gambia', 'score': 4.516, 'gdp_per_capita': 0.308},
#  {'country': 'Kenya', 'score': 4.5089999999999995, 'gdp_per_capita': 0.512},
#  {'country': 'Mauritania', 'score': 4.49, 'gdp_per_capita': 0.57},
#  {'country': 'Mozambique', 'score': 4.466, 'gdp_per_capita': 0.204},
#  {'country': 'Tunisia', 'score': 4.461, 'gdp_per_capita': 0.9209999999999999},
#  {'country': 'Bangladesh', 'score': 4.456, 'gdp_per_capita': 0.562},
#  {'country': 'Iraq', 'score': 4.437, 'gdp_per_capita': 1.043},
#  {'country': 'Congo (Kinshasa)', 'score': 4.418, 'gdp_per_capita': 0.094},
#  {'country': 'Mali', 'score': 4.39, 'gdp_per_capita': 0.385},
#  {'country': 'Sierra Leone', 'score': 4.374, 'gdp_per_capita': 0.268},
#  {'country': 'Sri Lanka',
#   'score': 4.3660000000000005,
#   'gdp_per_capita': 0.9490000000000001},
#  {'country': 'Myanmar', 'score': 4.36, 'gdp_per_capita': 0.71},
#  {'country': 'Chad', 'score': 4.35, 'gdp_per_capita': 0.35},
#  {'country': 'Ukraine', 'score': 4.332, 'gdp_per_capita': 0.82},
#  {'country': 'Ethiopia', 'score': 4.2860000000000005, 'gdp_per_capita': 0.336},
#  {'country': 'Swaziland',
#   'score': 4.212,
#   'gdp_per_capita': 0.8109999999999999},
#  {'country': 'Uganda', 'score': 4.189, 'gdp_per_capita': 0.332},
#  {'country': 'Egypt', 'score': 4.166, 'gdp_per_capita': 0.9129999999999999},
#  {'country': 'Zambia', 'score': 4.107, 'gdp_per_capita': 0.578},
#  {'country': 'Togo', 'score': 4.085, 'gdp_per_capita': 0.275},
#  {'country': 'India', 'score': 4.015, 'gdp_per_capita': 0.755},
#  {'country': 'Liberia', 'score': 3.975, 'gdp_per_capita': 0.073},
#  {'country': 'Comoros',
#   'score': 3.9730000000000003,
#   'gdp_per_capita': 0.27399999999999997},
#  {'country': 'Madagascar',
#   'score': 3.9330000000000003,
#   'gdp_per_capita': 0.27399999999999997},
#  {'country': 'Lesotho', 'score': 3.802, 'gdp_per_capita': 0.489},
#  {'country': 'Burundi', 'score': 3.775, 'gdp_per_capita': 0.046},
#  {'country': 'Zimbabwe', 'score': 3.6630000000000003, 'gdp_per_capita': 0.366},
#  {'country': 'Haiti', 'score': 3.597, 'gdp_per_capita': 0.32299999999999995},
#  {'country': 'Botswana', 'score': 3.488, 'gdp_per_capita': 1.041},
#  {'country': 'Syria', 'score': 3.4619999999999997, 'gdp_per_capita': 0.619},
#  {'country': 'Malawi', 'score': 3.41, 'gdp_per_capita': 0.191},
#  {'country': 'Yemen', 'score': 3.38, 'gdp_per_capita': 0.287},
#  {'country': 'Rwanda', 'score': 3.3339999999999996, 'gdp_per_capita': 0.359},
#  {'country': 'Tanzania',
#   'score': 3.2310000000000003,
#   'gdp_per_capita': 0.47600000000000003},
#  {'country': 'Afghanistan',
#   'score': 3.2030000000000003,
#   'gdp_per_capita': 0.35},
#  {'country': 'Central African Republic',
#   'score': 3.083,
#   'gdp_per_capita': 0.026000000000000002},
#  {'country': 'South Sudan', 'score': 2.853, 'gdp_per_capita': 0.306}]
